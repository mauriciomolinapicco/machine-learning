# %% [markdown]
# # Machine Learning
# ## Ejercicio semana 1
#
# Cargando en memoria un archivo CSV ubicado en un repositorio de mi github (sacado de kaggle.com) y mostrando los 10 primeros registros

# %%
import pandas as pd
#archivo csv cargado en mi github
url = "https://raw.githubusercontent.com/mauriciomolinapicco/machine-learning/refs/heads/master/dataset/Snitch_Fashion_Sales_Uncleaned.csv"
df = pd.read_csv(url)
df.head(10)
# Out:
#    Order_ID         Customer_Name Product_Category       Product_Name  \
# 0      1000        Brian Thompson            Jeans     Slim Fit Jeans
# 1      1001            Shaun Ross            Jeans     Slim Fit Jeans
# 2      1002          Sarah Snyder          Jackets        Puffer Coat
# 3      1003            Jay Briggs            Shoes            Loafers
# 4      1004           Maria Blake      Accessories              Belts
# 5      1005         Samuel Miller         T-Shirts           Crop Top
# 6      1006           John Mclean            Jeans    Boyfriend Jeans
# 7      1007  Dr. Kathryn Bass PhD          Dresses        Casual Midi
# 8      1008          Marie Fisher      Accessories         Sunglasses
# 9      1009            Dale Perry         T-Shirts  Oversized T-shirt
#
#    Units_Sold  Unit_Price  Discount_%  Sales_Amount  Order_Date       City  \
# 0         NaN      842.00        0.60          0.00  2025-02-27      Delhi
# ...

# %% [markdown]
# El dataset es un registro de ventas de productos de ropa. Tiene una pk que es el order_id la cual no se repite para ningun registro. Tambien tiene campos para producto, unidades vendidas, cant de unidades compradas, descuento aplicado, ciudad, profit, entre otros.

# %% [markdown]
# ### Mostrando los ultimos 5 registros del dataframe

# %%
df.tail()
# Out:
#       Order_ID      Customer_Name Product_Category       Product_Name  \
# 2495      3495     Allen Williams         T-Shirts  Oversized T-shirt
# 2496      3496      Jonathan Hill            Shoes            Loafers
# 2497      3497  Alejandro Cochran          Jackets      Bomber Jacket
# 2498      3498      Angela Adkins            Jeans       Straight Cut
# 2499      3499     Zachary Werner         T-Shirts        Graphic Tee
#
#       Units_Sold  Unit_Price  Discount_%  Sales_Amount  Order_Date       City  \
# 2495         NaN      848.79         NaN           0.0         NaN     Mumbai
# 2496         4.0         NaN         NaN           0.0  2024-03-10  Hyderabad
# 2497         NaN     3389.24        1.06           0.0         NaN  Ahmedabad
# 2498         5.0     3844.19         NaN           0.0  24-07-2024        Hyd
# 2499         6.0     1239.75         NaN           0.0         NaN     Mumbai
#
#      Segment   Profit
# 2495     NaN  2259.00
# 2496     B2B  2232.98
# ...

# %% [markdown]
# ### Informacion del dataframe (columnas, tipos, peso en memoria, etc)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Customer_Name     2500 non-null   object
#  2   Product_Category  2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Units_Sold        1194 non-null   float64
#  5   Unit_Price        1290 non-null   float64
#  6   Discount_%        849 non-null    float64
#  7   Sales_Amount      2500 non-null   float64
#  8   Order_Date        1894 non-null   object
#  9   City              2500 non-null   object
#  10  Segment           1679 non-null   object
#  11  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 234.5+ KB

# %% [markdown]
# ### Describe
# Generamos un resumen para los datos numericos, indicando maximos, minimos, media, entre otros

# %%
df.describe()
# Out:
#           Order_ID   Units_Sold   Unit_Price  Discount_%  Sales_Amount  \
# count  2500.000000  1194.000000  1290.000000  849.000000   2500.000000
# mean   2193.060000     1.940536  2691.715527    0.646466    126.756252
# std     748.063846     2.625680  1320.448967    0.380331   1464.944525
# min    1000.000000    -2.000000   400.210000    0.000000  -7518.330000
# 25%    1543.750000     0.000000  1526.195000    0.300000      0.000000
# 50%    2182.500000     2.000000  2685.985000    0.650000      0.000000
# 75%    2842.250000     4.000000  3824.347500    0.980000      0.000000
# max    3499.000000     6.000000  4998.910000    1.300000  29180.680000
#
#             Profit
# count  2500.000000
# mean    981.569032
# std    1159.159244
# min    -992.610000
# 25%     -19.670000
# 50%     947.885000
# 75%    1993.515000
# max    2997.110000

# %% [markdown]
# ## Features categoricos
# Recien vimos un resumen de los features numericos y algunas metricas. Loopeo sobre las columnas y las que son tipo 'object' significa que son de texto o categoricas. Imprimo las diferentes categorias o textos (en el caso de los nombres o ciudad) para cada columna NO numerica

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(f"Categorías en {col}: {df[col].unique()}")
# Out:
# Categorías en Customer_Name: ['Brian Thompson' 'Shaun Ross' 'Sarah Snyder' ... 'Alejandro Cochran'
#  'Angela Adkins' 'Zachary Werner']
# Categorías en Product_Category: ['Jeans' 'Jackets' 'Shoes' 'Accessories' 'T-Shirts' 'Dresses']
# Categorías en Product_Name: ['Slim Fit Jeans' 'Puffer Coat' 'Loafers' 'Belts' 'Crop Top'
#  'Boyfriend Jeans' 'Casual Midi' 'Sunglasses' 'Oversized T-shirt'
#  'Straight Cut' 'Sneakers' 'Maxi Dress' 'Wrap Dress' 'Slip-ons'
#  'Classic Tee' 'Bomber Jacket' 'Graphic Tee' 'Boots' 'Denim Jacket'
#  'Bodycon' 'Ripped Denim' 'Watches' 'Leather Jacket' 'Caps']
# Categorías en Order_Date: ['2025-02-27' '2025-07-15' '02-01-2025' ... '2024-08-15' '2023-12-31'
#  '25-11-2024']
# Categorías en City: ['Delhi' 'Ahmedabad' 'Mumbai' 'bengaluru' 'hyderbad' 'Bangalore' 'Pune'
#  'Hyd' 'Hyderabad']
# Categorías en Segment: ['B2C' nan 'B2B']

# %%
#mostrando solamente las columnas descuento y profit, se podria analizar la relacion
df[['Discount_%', 'Profit']]
# Out:
#       Discount_%   Profit
# 0           0.60  2137.45
# 1            NaN  1588.15
# 2            NaN  -158.03
# 3            NaN  2296.50
# 4           0.27    63.66
# ...          ...      ...
# 2495         NaN  2259.00
# 2496         NaN  2232.98
# 2497        1.06  1955.31
# 2498         NaN  2967.00
# 2499         NaN   715.15
#
# [2500 rows x 2 columns]

# %% [raw]
# Un ejemplo de label podria ser el profit, que al fin y al cabo es muy importante para los negocios poder predecir esto. Como ya tenemos los datos historicos del profit el tipo de aprendizaje seria APRENDIZAJE SUPERVISADO y al ser un valor numerico es un modelo de REGRESION. El modelo tomaria el resto de datos como entrada y haria una estimacion del profit de la venta.
# Otra opcion podria ser realizar una clasificacion de clientes en base a sus compras anteriores, crear categorias en base a que que tan frecuente compran y cuando lo hacen cuanto profit dejan a la empresa por ejemplo. Este seria un aprendizaje NO SUPERVISADO ya que estamos no tenemos un label predefinido, sino que buscamos agrupar clientes en base a datos de compras pasados
